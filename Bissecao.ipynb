# %%
def bissecao(f,a,b,prec):
    """ Método da bisseção para uma função f no intervalo [a,b]. """
    m = (a+b)/2
    # Se já há precisão suficiente, retornamos o ponto médio do intervalo
    if abs(b - a) < prec: return m
    # Se f(m) == 0, achamos uma raiz exata!
    if f(m) == 0: return m

    # Senão, vamos por recorrência
    if f(m)*f(a) < 0: return bissecao(f,a,m,prec)
    else: return bissecao(f,m,b,prec)

# %% [markdown]
# Caso 1: Transferencia de Calor

# %%
def funcao(x):
    return 84.19 + x*(((x**2) +(y**2))**1/2)*((x**2)+(y**2))**1/2

# %%
bissecao(funcao, -1, 10, 1e-6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ca6d560f5276> in <module>()
# ----> 1 bissecao(funcao, -1, 10, 1e-6)
#
# <ipython-input-9-f2078071e521> in bissecao(f, a, b, prec)
#       5     if abs(b - a) < prec: return m
#       6     # Se f(m) == 0, achamos uma raiz exata!
# ----> 7     if f(m) == 0: return m
#       8
#       9     # Senão, vamos por recorrência
#
# <ipython-input-14-cd78e97f2c31> in funcao(x)
#       1 def funcao(x):
# ----> 2     return 84.19 + x*(((x**2) +(y**2))**1/2)*((x**2)+(y**2))**1/2
#
# NameError: name 'y' is not defined

# %% [markdown]
# Caso 2: Calculo da taxa de juros a serem cobrados a uma contratora

# %%
def equa(x):
    return (48000*x*((1+x)**4/(((1+x)**4)-1)))-18000

# %%
bissecao(equa, 0.01,0.99, 1e-6)
# Out:
# 0.18450446128845222
